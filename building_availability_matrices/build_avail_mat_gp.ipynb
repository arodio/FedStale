# %%
import matplotlib.pyplot as plt
import pickle

from gaussian_process_models.experiments import exp1


res = exp1(freq1=0.6)

# TODO: Change the file location
# with open("gp_avail_mat.pkl", "wb") as f:
#     pickle.dump(res, f, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# 2024-10-08 16:13:11.612134: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-10-08 16:13:11.616036: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-10-08 16:13:11.627294: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-08 16:13:11.644956: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-08 16:13:11.650182: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
fig, axs = plt.subplots(len(res.keys()), 1, figsize=(6, 12))

# Plot each array using imshow
for i, ty in enumerate(res.keys()):
    axs[i].imshow(res[ty], cmap="binary")
    axs[i].set_title(ty)

# Adjust layout
plt.tight_layout()

# TODO: Change file location
# plt.savefig("gp_avail_mat.png")

# %%
import numpy as np

# %%
print(np.sum(res['corr'], axis=1))
print(np.sum(res['uncorr'], axis=1))
print(np.sum(res['corr_fine_tuning'], axis=1))
print(np.sum(res['uncorr_fine_tuning'], axis=1))
# Out:
# [60 60 60 60 60 60 60]
# [60 60 60 60 60 60 60]
# [60. 60. 60. 60. 60. 60. 60.]
# [60. 60. 60. 60. 60. 60. 60.]
