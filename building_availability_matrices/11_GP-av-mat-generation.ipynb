# %% [markdown]
# # Generation of Gaussian Process based availability matrices
#
# In this notebook we generate various availability matrices by means of Gaussian Processes, with and without a fine-tuning phase at the end.
#
# At the moment this code accounts for time correlation, with homogeneous or hetergogeneous participation frequencies. It does not account for spatial correlation.
#
# **Import libraries:**

# %%
from av_mat_generation.GP_based.gp import GP
import numpy as np

MAIN_FOLDER = 'availability_matrices/av-mat-7'
# Out:
# 2025-04-17 16:11:16.513202: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1744899076.525444  120735 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1744899076.529229  120735 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1744899076.538462  120735 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1744899076.538478  120735 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1744899076.538479  120735 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1744899076.538480  120735 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-04-17 16:11:16.541503: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Generation of availablity matrices

# %%
freq_seq = np.array([0.20, 0.30, 0.40, 0.50, 0.60, 0.70, 0.80])
gp = GP(freq=freq_seq, k=3, out_folder=MAIN_FOLDER)
gp.create_all_av_mat()

# freq_seq = 0.5
# gp = GP(freq=freq_seq, out_folder=MAIN_FOLDER)
# gp.create_all_av_mat()
