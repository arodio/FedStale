# %% [markdown]
# # Generation of Gaussian Process based availability matrices
#
# In this notebook we generate various availability matrices by means of Gaussian Processes, with and without a fine-tuning phase at the end.
#
# At the moment this code accounts for time correlation, with homogeneous or hetergogeneous participation frequencies. It does not account for spatial correlation.
#
# **Import libraries:**

# %%
from av_mat_generation.GP_based.gp import GP
import numpy as np

MAIN_FOLDER = 'availability_matrices/av-mat-8'
# Out:
# 2025-04-29 16:27:59.135396: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745936879.147654 1278412 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745936879.151292 1278412 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1745936879.160528 1278412 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %% [markdown]
# ## Generation of availablity matrices

# %%
freq_seq = np.array([0.25, 0.25, 0.50, 0.50, 0.50, 0.75, 0.75])
gp = GP(freq=freq_seq, out_folder=MAIN_FOLDER, n_rounds=100, k=10)
gp.create_all_av_mat()

freq_seq = np.array([0.20, 0.30, 0.40, 0.50, 0.60, 0.70, 0.80])
gp = GP(freq=freq_seq, out_folder=MAIN_FOLDER, n_rounds=100, k=10)
gp.create_all_av_mat()

freq_seq = 0.35
gp = GP(freq=freq_seq, out_folder=MAIN_FOLDER, n_rounds=100, k=10)
gp.create_all_av_mat()

freq_seq = 0.5
gp = GP(freq=freq_seq, out_folder=MAIN_FOLDER, n_rounds=100, k=10)
gp.create_all_av_mat()
# Out:
# I0000 00:00:1745936882.048696 1278412 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6109 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2080 SUPER, pci bus id: 0000:01:00.0, compute capability: 7.5
# I0000 00:00:1745936882.049047 1278412 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 6799 MB memory:  -> device: 1, name: NVIDIA GeForce RTX 2080 SUPER, pci bus id: 0000:02:00.0, compute capability: 7.5
